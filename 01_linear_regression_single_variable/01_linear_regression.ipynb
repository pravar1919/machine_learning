# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('property.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel("Area (sq ft)")
plt.ylabel("Price (US$)")
plt.scatter(df.area, df.price, color='red', marker='+')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
reg.predict([[1]])
# Out:
# /home/home/Documents/Projects/machine_learning/env/lib/python3.10/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([180752.2260274])

# %%
d = pd.read_csv('areas.csv')
d
# Out:
#      area
# 0    1000
# 1    1500
# 2    2300
# 3    3540
# 4    4120
# 5    4560
# 6    5050
# 7    5690
# 8    6123
# 9    2300
# 10   7500
# 11   9800
# 12  10000

# %%
p = reg.predict(d)

# %%
d['price'] = p

# %%
d
# Out:
#      area         price
# 0    1000  3.164041e+05
# 1    1500  3.842979e+05
# 2    2300  4.929281e+05
# 3    3540  6.613048e+05
# 4    4120  7.400616e+05
# 5    4560  7.998082e+05
# 6    5050  8.663442e+05
# 7    5690  9.532483e+05
# 8    6123  1.012044e+06
# 9    2300  4.929281e+05
# 10   7500  1.199024e+06
# 11   9800  1.511336e+06
# 12  10000  1.538493e+06

# %%
d.to_csv("prediction.csv", index=False)

# %%
plt.xlabel("Area (sq ft)")
plt.ylabel("Price (US$)")
plt.scatter(df.area, df.price, color='red', marker='+')
# the below is the predicted line
plt.plot(df.area, reg.predict(df[['area']]), color='blue')
