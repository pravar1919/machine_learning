# %%
import pandas as pd
from sklearn.datasets import load_iris
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
iris = load_iris()
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
df = pd.DataFrame(iris.data)

# %%
df['target'] = iris.target
df
# Out:
#        0    1    2    3  target
# 0    5.1  3.5  1.4  0.2       0
# 1    4.9  3.0  1.4  0.2       0
# 2    4.7  3.2  1.3  0.2       0
# 3    4.6  3.1  1.5  0.2       0
# 4    5.0  3.6  1.4  0.2       0
# ..   ...  ...  ...  ...     ...
# 145  6.7  3.0  5.2  2.3       2
# 146  6.3  2.5  5.0  1.9       2
# 147  6.5  3.0  5.2  2.0       2
# 148  6.2  3.4  5.4  2.3       2
# 149  5.9  3.0  5.1  1.8       2
#
# [150 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('target', axis="columns"), df.target, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
model.score(X_test, y_test)
# Out:
# 1.0

# %%
y_predicted = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predicted)

# %%
import seaborn as sns
sns.heatmap(cm, annot=True)
# Out:
# <Axes: >

# %%
scores=[ ]
n_estimators=range(1,51)  #example
for i in n_estimators :
    model=RandomForestClassifier(n_estimators=i)
    model.fit(X_train,y_train)
    scores.append(model.score(X_test,y_test))
    print('score:{}, n_estimator:{}'.format(scores[i-1],i))

plt.plot(n_estimators,scores)
plt.xlabel('n_estimators')
plt.ylabel(('testing accuracy'))
# Out:
# score:0.9333333333333333, n_estimator:1
# score:0.9666666666666667, n_estimator:2
# score:1.0, n_estimator:3
# score:0.9666666666666667, n_estimator:4
# score:0.9333333333333333, n_estimator:5
# score:0.9666666666666667, n_estimator:6
# score:1.0, n_estimator:7
# score:0.9666666666666667, n_estimator:8
# score:1.0, n_estimator:9
# score:1.0, n_estimator:10
# score:0.9666666666666667, n_estimator:11
# score:0.9666666666666667, n_estimator:12
# score:1.0, n_estimator:13
# score:1.0, n_estimator:14
# score:1.0, n_estimator:15
# score:0.9333333333333333, n_estimator:16
# score:0.9666666666666667, n_estimator:17
# score:0.9666666666666667, n_estimator:18
# score:1.0, n_estimator:19
# score:1.0, n_estimator:20
# score:0.9666666666666667, n_estimator:21
# score:1.0, n_estimator:22
# score:1.0, n_estimator:23
# score:0.9666666666666667, n_estimator:24
# score:1.0, n_estimator:25
# score:1.0, n_estimator:26
# score:1.0, n_estimator:27
# score:0.9666666666666667, n_estimator:28
# score:1.0, n_estimator:29
# score:1.0, n_estimator:30
# score:0.9666666666666667, n_estimator:31
# score:1.0, n_estimator:32
# score:1.0, n_estimator:33
# score:1.0, n_estimator:34
# score:1.0, n_estimator:35
# score:1.0, n_estimator:36
# score:0.9666666666666667, n_estimator:37
# score:1.0, n_estimator:38
# score:1.0, n_estimator:39
# score:1.0, n_estimator:40
# score:1.0, n_estimator:41
# score:1.0, n_estimator:42
# score:0.9666666666666667, n_estimator:43
# score:1.0, n_estimator:44
# score:1.0, n_estimator:45
# score:1.0, n_estimator:46
# score:1.0, n_estimator:47
# score:0.9666666666666667, n_estimator:48
# score:0.9666666666666667, n_estimator:49
# score:0.9666666666666667, n_estimator:50
# Text(0, 0.5, 'testing accuracy')
